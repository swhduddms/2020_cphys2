# %%
# 2. SVM 분석

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.datasets import load_iris

iris = load_iris()

# %%
from sklearn.model_selection import train_test_split

col1 = 0
col2 = 1

# %%
X = iris.data[:,[col1,col2]] 
y = iris.target.copy()
y[y==0] = 2
y[y==1] = 0
y[y==2] = 1

X_train, X_test, y_train, y_test = train_test_split(X, y)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((112, 2), (38, 2), (112,), (38,))

# %%
plt.figure(figsize=[10,8])
plt.scatter(X[:,0], X[:,1], c=y)
plt.colorbar()

# %%
from sklearn.svm import LinearSVC

model = LinearSVC(C=1)
model.fit(X_train, y_train)

score = model.score(X_test, y_test)
print(score)
# Out:
# 0.7631578947368421
# C:\Users\swhdu\anaconda3\lib\site-packages\sklearn\svm\_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "

# %% [markdown]
# 분석 결과 : 꽃받침의 길이와 꽃잎의 넓이를 선정하여 setosa-0, setosa가 아닌 것들은 1로 하여 분석하였다.
